# %% [markdown]
# 1. На основе учебного ноутбука проведите финальную подготовку данных. Измените количество сегментирующих классов с `16` на `7`:
#   - 0_класс - FLOOR
#   - 1_класс - CEILING
#   - 2_класс - WALL
#   - 3_класс - APERTURE, DOOR, WINDOW
#   - 4_класс - COLUMN, RAILINGS, LADDER
#   - 5_класс - INVENTORY
#   - 6_класс - LAMP, WIRE, BEAM, EXTERNAL, BATTERY,
# PEOPLE
#
# 2. Изучите внимательно особенности `U-net`, определите в чем принципиальное отличие  `U-net `  и   `simpleUnet` из учебного ноутбука.
#
# 3. Доработайте `simpleUnet` с учетом особенностей `U-net `. Обучите модель на 100 эпохах и визуализируйте результат.
#
# **Важно!**
#
# Многие эксперименты могут приводить к переполнению ОЗУ в вашем ноутбуке и сброса кода обучения.
#
# ![image.png](data:image/png;base64,...)
#
# Для предотвращения переполнения ОЗУ может помочь библиотека `gc`. Вставьте строчку `gc.collect()` в цикл ваших экспериментов для сбора и удаления временных данных (кеш).

# %% [markdown]
# Перед выполнением задания, пожалуйста, запустите ячейку `Подготовка` ниже:

# %% [markdown]
# ## Подготовка

# %% [markdown]
# ### Импорт библиотек

# %%
 # Импортируем модели keras: Model
from tensorflow.keras.models import Model

 # Импортируем стандартные слои keras
from tensorflow.keras.layers import Input, Conv2DTranspose, concatenate, Activation
from tensorflow.keras.layers import MaxPooling2D, Conv2D, BatchNormalization, UpSampling2D

# Импортируем оптимизатор Adam
from tensorflow.keras.optimizers import Adam

# Импортируем модуль pyplot библиотеки matplotlib для построения графиков
import matplotlib.pyplot as plt

# Импортируем модуль image для работы с изображениями
from tensorflow.keras.preprocessing import image

# Импортируем библиотеку numpy
import numpy as np

# Импортируем методделения выборки
from sklearn.model_selection import train_test_split

# загрузка файлов по HTML ссылке
import gdown

# Для работы с файлами
import os

# Для генерации случайных чисел
import random

import time

# импортируем модель Image для работы с изображениями
from PIL import Image

# очистка ОЗУ
import gc

# %% [markdown]
# ### Загрузка датасета
#
# грузим и распаковываем архив картинок

# %%
# Загрузка датасета из облака

gdown.download('https://storage.yandexcloud.net/aiueducation/Content/base/l14/construction_256x192.zip', None, quiet=False)
#gdown.download('https://storage.yandexcloud.net/aiueducation/Content/base/l14/construction_512x384.zip', None, quiet=False)

# !unzip -q 'construction_256x192.zip' # распоковываем архив
# Out:
# Downloading...
# From: https://storage.yandexcloud.net/aiueducation/Content/base/l14/construction_256x192.zip
# To: /content/construction_256x192.zip
# 100%|██████████| 214M/214M [00:09<00:00, 22.3MB/s]

# %% [markdown]
# ### Предварительная подготовка данных

# %%
# Глобальные параметры

IMG_WIDTH = 192               # Ширина картинки
IMG_HEIGHT = 256             # Высота картинки
NUM_CLASSES = 16              # Задаем количество классов на изображении
TRAIN_DIRECTORY = 'train'     # Название папки с файлами обучающей выборки
VAL_DIRECTORY = 'val'         # Название папки с файлами проверочной выборки

# %% [markdown]
# Загрузим оригинальные изображения (код из лекции):

# %%
train_images = [] # Создаем пустой список для хранений оригинальных изображений обучающей выборки
val_images = [] # Создаем пустой список для хранений оригинальных изображений проверочной выборки

cur_time = time.time()  # Засекаем текущее время

# Проходим по всем файлам в каталоге по указанному пути
for filename in sorted(os.listdir(TRAIN_DIRECTORY+'/original')):
    # Читаем очередную картинку и добавляем ее в список изображений с указанным target_size
    train_images.append(image.load_img(os.path.join(TRAIN_DIRECTORY+'/original',filename),
                                       target_size=(IMG_WIDTH, IMG_HEIGHT)))

# Отображаем время загрузки картинок обучающей выборки
print ('Обучающая выборка загружена. Время загрузки: ', round(time.time() - cur_time, 2), 'c', sep='')

# Отображаем количество элементов в обучающей выборке
print ('Количество изображений: ', len(train_images))

cur_time = time.time() # Засекаем текущее время

# Проходим по всем файлам в каталоге по указанному пути
for filename in sorted(os.listdir(VAL_DIRECTORY+'/original')):
    # Читаем очередную картинку и добавляем ее в список изображений с указанным target_size
    val_images.append(image.load_img(os.path.join(VAL_DIRECTORY+'/original',filename),
                                     target_size=(IMG_WIDTH, IMG_HEIGHT)))

# Отображаем время загрузки картинок проверочной выборки
print ('Проверочная выборка загружена. Время загрузки: ', round(time.time() - cur_time, 2), 'c', sep='')

# Отображаем количество элементов в проверочной выборке
print ('Количество изображений: ', len(val_images))
# Out:
# Обучающая выборка загружена. Время загрузки: 0.42c
# Количество изображений:  1900
# Проверочная выборка загружена. Время загрузки: 0.01c
# Количество изображений:  100

# %% [markdown]
# Загрузим сегментированные изображения (код из лекции):

# %%
train_segments = [] # Создаем пустой список для хранений оригинальных изображений обучающей выборки
val_segments = [] # Создаем пустой список для хранений оригинальных изображений проверочной выборки

cur_time = time.time() # Засекаем текущее время

for filename in sorted(os.listdir(TRAIN_DIRECTORY+'/segment')): # Проходим по всем файлам в каталоге по указанному пути
    # Читаем очередную картинку и добавляем ее в список изображений с указанным target_size
    train_segments.append(image.load_img(os.path.join(TRAIN_DIRECTORY+'/segment',filename),
                                       target_size=(IMG_WIDTH, IMG_HEIGHT)))

# Отображаем время загрузки картинок обучающей выборки
print ('Обучающая выборка загружена. Время загрузки: ', round(time.time() - cur_time, 2), 'c', sep='')

# Отображаем количество элементов в обучающем наборе сегментированных изображений
print ('Количество изображений: ', len(train_segments))

cur_time = time.time() # Засекаем текущее время

for filename in sorted(os.listdir(VAL_DIRECTORY+'/segment')): # Проходим по всем файлам в каталоге по указанному пути
    # Читаем очередную картинку и добавляем ее в список изображений с указанным target_size
    val_segments.append(image.load_img(os.path.join(VAL_DIRECTORY+'/segment',filename),
                                     target_size=(IMG_WIDTH, IMG_HEIGHT)))

# Отображаем время загрузки картинок проверочной выборки
print ('Проверочная выборка загружена. Время загрузки: ', round(time.time() - cur_time, 2), 'c', sep='')

# Отображаем количество элементов в проверочном наборе сегментированных изображений
print ('Количество изображений: ', len(val_segments))
# Out:
# Обучающая выборка загружена. Время загрузки: 0.25c
# Количество изображений:  1900
# Проверочная выборка загружена. Время загрузки: 0.02c
# Количество изображений:  100

# %% [markdown]
# ## Решение

# %%
FLOOR = (100, 100, 100)         # Пол (Серый)
CEILING = (0, 0, 100)           # Потолок (Синий)
WALL = (0, 100, 0)              # Стена (Зелёный)
APERTURE = (0, 100, 100)        # Проем (Темно-бирюзовый)
DOOR = (100, 0, 100)            # Дверь (Бордовый)
WINDOW = (100, 100, 0)          # Окно (Золотой)
COLUMN = (100, 0, 0)            # Колонна (Красный)
RAILINGS = (0, 200, 0)          # Перила (Светло-зелёный)
LADDER = (0, 0, 200)            # Лестница (Светло-синий)
INVENTORY = (200, 0, 200)       # Инвентарь (Розовый)
LAMP = (200, 200, 0)            # Лампа (Жёлтый)
WIRE = (0, 100, 200)            # Провод (Голубой)
BEAM = (100, 0, 200)            # Балка (Фиолетовый)
EXTERNAL = (200, 200, 200)      # Внешний мир (Светло-серый)
BATTERY = (200, 0, 0)           # Батареи (Светло-красный)
PEOPLE = (0, 200, 200)          # Люди (Бирюзовый)
# Список меток семи классов
NEW_CLASS_LABELS = (FLOOR, CEILING, WALL, APERTURE, COLUMN, INVENTORY, LAMP)
NUM_CLASSES = 7  # Теперь классов 7
# Функция преобразования цветного изображения в метки классов (7 классов)
def rgb_to_labels(image_list):
    result = []
    for d in image_list:
        sample = np.array(d)
        y = np.zeros((IMG_WIDTH, IMG_HEIGHT, 1), dtype='uint8')
        # FLOOR
        y[np.where(np.all(sample == FLOOR, axis=-1))] = 0
        # CEILING
        y[np.where(np.all(sample == CEILING, axis=-1))] = 1
        # WALL
        y[np.where(np.all(sample == WALL, axis=-1))] = 2
        # APERTURE, DOOR, WINDOW
        y[np.where(np.all(sample == APERTURE, axis=-1))] = 3
        y[np.where(np.all(sample == DOOR, axis=-1))] = 3
        y[np.where(np.all(sample == WINDOW, axis=-1))] = 3
        # COLUMN, RAILINGS, LADDER
        y[np.where(np.all(sample == COLUMN, axis=-1))] = 4
        y[np.where(np.all(sample == RAILINGS, axis=-1))] = 4
        y[np.where(np.all(sample == LADDER, axis=-1))] = 4
        # INVENTORY
        y[np.where(np.all(sample == INVENTORY, axis=-1))] = 5
        # LAMP, WIRE, BEAM, EXTERNAL, BATTERY, PEOPLE
        y[np.where(np.all(sample == LAMP, axis=-1))] = 6
        y[np.where(np.all(sample == WIRE, axis=-1))] = 6
        y[np.where(np.all(sample == BEAM, axis=-1))] = 6
        y[np.where(np.all(sample == EXTERNAL, axis=-1))] = 6
        y[np.where(np.all(sample == BATTERY, axis=-1))] = 6
        y[np.where(np.all(sample == PEOPLE, axis=-1))] = 6
        result.append(y)
    return np.array(result)

# Из метки в цветное изображение
def labels_to_rgb(image_list):
    result = []
    for y in image_list:
        temp = np.zeros((IMG_WIDTH, IMG_HEIGHT, 3), dtype='uint8')
        # FLOOR (Серый)
        temp[np.where(np.all(y==0, axis=-1))] = FLOOR
        # CEILING (Синий)
        temp[np.where(np.all(y==1, axis=-1))] = CEILING
        # WALL (Зеленый)
        temp[np.where(np.all(y==2, axis=-1))] = WALL
        # APERTURE (Тёмно-бирюзовый)
        temp[np.where(np.all(y==3, axis=-1))] = APERTURE
        # COLUMN (Красный)
        temp[np.where(np.all(y==4, axis=-1))] = COLUMN
        # INVENTORY (Розовый)
        temp[np.where(np.all(y==5, axis=-1))] = INVENTORY
        # LAMP (Жёлтый)
        temp[np.where(np.all(y==6, axis=-1))] = LAMP
        result.append(temp)
    return np.array(result)

# %%
def improved_simple_unet(class_count, input_shape):
    img_input = Input(input_shape)
    # Block 1
    x = Conv2D(32, (3, 3), padding='same', name='block1_conv1')(img_input)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Conv2D(32, (3, 3), padding='same', name='block1_conv2')(x)
    x = BatchNormalization()(x)
    block_1_out = Activation('relu')(x)
    x = MaxPooling2D((2, 2))(block_1_out)

    # Block 2
    x = Conv2D(64, (3, 3), padding='same', name='block2_conv1')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Conv2D(64, (3, 3), padding='same', name='block2_conv2')(x)
    x = BatchNormalization()(x)
    block_2_out = Activation('relu')(x)
    x = MaxPooling2D((2, 2))(block_2_out)

    # Block 3
    x = Conv2D(128, (3, 3), padding='same', name='block3_conv1')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Conv2D(128, (3, 3), padding='same', name='block3_conv2')(x)
    x = BatchNormalization()(x)
    block_3_out = Activation('relu')(x)
    x = MaxPooling2D((2, 2))(block_3_out)

    # Block 4
    x = Conv2D(256, (3, 3), padding='same', name='block4_conv1')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Conv2D(256, (3, 3), padding='same', name='block4_conv2')(x)
    x = BatchNormalization()(x)
    block_4_out = Activation('relu')(x)
    x = MaxPooling2D((2, 2))(block_4_out)

    # UP 1
    x = Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = concatenate([x, block_4_out])
    x = Conv2D(256, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    # UP 2
    x = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = concatenate([x, block_3_out])
    x = Conv2D(128, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    # UP 3
    x = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = concatenate([x, block_2_out])
    x = Conv2D(64, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    # UP 4
    x = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = concatenate([x, block_1_out])
    x = Conv2D(32, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Conv2D(class_count, (3, 3), activation='softmax', padding='same')(x)
    model = Model(img_input, x)
    model.compile(optimizer=Adam,
                  loss='sparse_categorical_crossentropy',
                  metrics=['sparse_categorical_accuracy'])
    return model

# %%
# Входные изображения в numpy массивы
x_train = np.array([image.img_to_array(img) for img in train_images])
x_val = np.array([image.img_to_array(img) for img in val_images])
# Сегментированные изображения в метки семи классов
y_train = rgb_to_labels(train_segments)
y_val = rgb_to_labels(val_segments)

# %%
import tensorflow as tf
with tf.device('/GPU:0'):
    model_improved = improved_simple_unet(NUM_CLASSES, (IMG_WIDTH, IMG_HEIGHT, 3))
    model_improved.summary()
    history = model_improved.fit(x_train, y_train,
                                epochs=100, batch_size=32,
                                validation_data=(x_val, y_val))
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 192, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv1        │ (None, 192, 256,  │        896 │ input_layer[0][0] │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 192, 256,  │        128 │ block1_conv1[0][… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 192, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv2        │ (None, 192, 256,  │      9,248 │ activation[0][0]  │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 192, 256,  │        128 │ block1_conv2[0][… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 192, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 96, 128,   │          0 │ activation_1[0][… │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_conv1        │ (None, 96, 128,   │     18,496 │ max_pooling2d[0]… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 96, 128,   │        256 │ block2_conv1[0][… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 96, 128,   │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_conv2        │ (None, 96, 128,   │     36,928 │ activation_2[0][… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 96, 128,   │        256 │ block2_conv2[0][… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 96, 128,   │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 48, 64,    │          0 │ activation_3[0][… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_conv1        │ (None, 48, 64,    │     73,856 │ max_pooling2d_1[… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 48, 64,    │        512 │ block3_conv1[0][… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 48, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_conv2        │ (None, 48, 64,    │    147,584 │ activation_4[0][… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 48, 64,    │        512 │ block3_conv2[0][… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 48, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 24, 32,    │          0 │ activation_5[0][… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_conv1        │ (None, 24, 32,    │    295,168 │ max_pooling2d_2[… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 24, 32,    │      1,024 │ block4_conv1[0][… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (None, 24, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_conv2        │ (None, 24, 32,    │    590,080 │ activation_6[0][… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 24, 32,    │      1,024 │ block4_conv2[0][… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (None, 24, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 12, 16,    │          0 │ activation_7[0][… │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose    │ (None, 24, 32,    │    262,400 │ max_pooling2d_3[… │
# │ (Conv2DTranspose)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 24, 32,    │      1,024 │ conv2d_transpose… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_8        │ (None, 24, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 24, 32,    │          0 │ activation_8[0][… │
# │ (Concatenate)       │ 512)              │            │ activation_7[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 24, 32,    │  1,179,904 │ concatenate[0][0] │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 24, 32,    │      1,024 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_9        │ (None, 24, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_1  │ (None, 48, 64,    │    131,200 │ activation_9[0][… │
# │ (Conv2DTranspose)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 48, 64,    │        512 │ conv2d_transpose… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_10       │ (None, 48, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 48, 64,    │          0 │ activation_10[0]… │
# │ (Concatenate)       │ 256)              │            │ activation_5[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 48, 64,    │    295,040 │ concatenate_1[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 48, 64,    │        512 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_11       │ (None, 48, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_2  │ (None, 96, 128,   │     32,832 │ activation_11[0]… │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 96, 128,   │        256 │ conv2d_transpose… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_12       │ (None, 96, 128,   │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 96, 128,   │          0 │ activation_12[0]… │
# │ (Concatenate)       │ 128)              │            │ activation_3[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 96, 128,   │     73,792 │ concatenate_2[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 96, 128,   │        256 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_13       │ (None, 96, 128,   │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_3  │ (None, 192, 256,  │      8,224 │ activation_13[0]… │
# │ (Conv2DTranspose)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 192, 256,  │        128 │ conv2d_transpose… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_14       │ (None, 192, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 192, 256,  │          0 │ activation_14[0]… │
# │ (Concatenate)       │ 64)               │            │ activation_1[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 192, 256,  │     18,464 │ concatenate_3[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 192, 256,  │        128 │ conv2d_3[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_15       │ (None, 192, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 192, 256,  │      2,023 │ activation_15[0]… │
# │                     │ 7)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 3,183,815 (12.15 MB)
#  Trainable params: 3,179,975 (12.13 MB)
#  Non-trainable params: 3,840 (15.00 KB)
# Epoch 1/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 101s 836ms/step - loss: 1.6326 - sparse_categorical_accuracy: 0.4188 - val_loss: 10.1224 - val_sparse_categorical_accuracy: 0.1494
# Epoch 2/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 72s 362ms/step - loss: 0.9718 - sparse_categorical_accuracy: 0.6685 - val_loss: 1.3263 - val_sparse_categorical_accuracy: 0.5590
# Epoch 3/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 42s 374ms/step - loss: 0.8577 - sparse_categorical_accuracy: 0.7060 - val_loss: 1.5736 - val_sparse_categorical_accuracy: 0.5526
# Epoch 4/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 41s 381ms/step
100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 41s 380ms/step - loss: 0.1642 - sparse_categorical_accuracy: 0.9422 - val_loss: 1.0512 - val_sparse_categorical_accuracy: 0.7169
# Epoch 47/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 41s 373ms/step - loss: 0.1532 - sparse_categorical_accuracy: 0.9463 - val_loss: 1.3820 - val_sparse_categorical_accuracy: 0.6779
# Epoch 48/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 41s 381ms/step - loss: 0.1674 - sparse_categorical_accuracy: 0.9406 - val_loss: 1.1374 - val_sparse_categorical_accuracy: 0.7031
# Epoch 49/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 41s 374ms/step - loss: 0.1662 - sparse_categorical_accuracy: 0.9413 - val_loss: 1.1106 - val_sparse_categorical_accuracy: 0.7007
# Epoch 50/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 42s 383ms/step - loss: 0.1633 - sparse_categorical_accuracy: 0.9423 - val_loss: 1.2226 - val_sparse_categorical_accuracy: 0.7149
# Epoch 51/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 40s 374ms/step - loss: 0.1612 - sparse_categorical_accuracy: 0.9429 - val_loss: 1.0922 - val_sparse_categorical_accuracy: 0.7313
# Epoch 52/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 41s 378ms/step - loss: 0.1494 - sparse_categorical_accuracy: 0.9473 - val_loss: 1.1070 - val_sparse_categorical_accuracy: 0.7252
# Epoch 53/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 41s 375ms/step - loss: 0.1434 - sparse_categorical_accuracy: 0.9495 - val_loss: 1.1509 - val_sparse_categorical_accuracy: 0.7204
# Epoch 54/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 41s 378ms/step - loss: 0.1332 - sparse_categorical_accuracy: 0.9529 - val_loss: 1.1547 - val_sparse_categorical_accuracy: 0.7239
# Epoch 55/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 41s 376ms/step - loss: 0.1282 - sparse_categorical_accuracy: 0.9548 - val_loss: 1.1948 - val_sparse_categorical_accuracy: 0.7301
# Epoch 56/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 23s 381ms/step - loss: 0.1244 - sparse_categorical_accuracy: 0.9560 - val_loss: 1.1573 - val_sparse_categorical_accuracy: 0.7230
# Epoch 57/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 41s 375ms/step - loss: 0.1301 - sparse_categorical_accuracy: 0.9538 - val_loss: 1.2059 - val_sparse_categorical_accuracy: 0.7259
# Epoch 58/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 41s 381ms/step - loss: 0.1377 - sparse_categorical_accuracy: 0.9514 - val_loss: 1.1871 - val_sparse_categorical_accuracy: 0.7257
# Epoch 59/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 41s 378ms/step - loss: 0.1189 - sparse_categorical_accuracy: 0.9574 - val_loss: 1.2055 - val_sparse_categorical_accuracy: 0.7278
# Epoch 60/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 41s 379ms/step - loss: 0.1147 - sparse_categorical_accuracy: 0.9592 - val_loss: 1.2541 - val_sparse_categorical_accuracy: 0.7269
# Epoch 61/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 41s 374ms/step - loss: 0.1116 - sparse_categorical_accuracy: 0.9601 - val_loss: 1.3221 - val_sparse_categorical_accuracy: 0.6882
# Epoch 62/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 41s 378ms/step - loss: 0.1236 - sparse_categorical_accuracy: 0.9558 - val_loss: 1.3027 - val_sparse_categorical_accuracy: 0.7132
# Epoch 63/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 23s 382ms/step - loss: 0.1115 - sparse_categorical_accuracy: 0.9602 - val_loss: 1.2214 - val_sparse_categorical_accuracy: 0.7301
# Epoch 64/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 40s 370ms/step - loss: 0.1026 - sparse_categorical_accuracy: 0.9633 - val_loss: 1.3427 - val_sparse_categorical_accuracy: 0.7103
# Epoch 65/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 42s 380ms/step - loss: 0.1691 - sparse_categorical_accuracy: 0.9407 - val_loss: 1.4631 - val_sparse_categorical_accuracy: 0.6956
# Epoch 66/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 41s 378ms/step
100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 42s 380ms/step - loss: 0.0907 - sparse_categorical_accuracy: 0.9672 - val_loss: 1.6401 - val_sparse_categorical_accuracy: 0.7073
# Epoch 87/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 41s 377ms/step - loss: 0.1319 - sparse_categorical_accuracy: 0.9527 - val_loss: 1.4921 - val_sparse_categorical_accuracy: 0.6929
# Epoch 88/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 41s 386ms/step - loss: 0.1054 - sparse_categorical_accuracy: 0.9619 - val_loss: 1.5638 - val_sparse_categorical_accuracy: 0.7061
# Epoch 89/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 40s 377ms/step - loss: 0.1062 - sparse_categorical_accuracy: 0.9618 - val_loss: 1.4671 - val_sparse_categorical_accuracy: 0.7124
# Epoch 90/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 41s 381ms/step - loss: 0.0898 - sparse_categorical_accuracy: 0.9676 - val_loss: 1.3202 - val_sparse_categorical_accuracy: 0.7304
# Epoch 91/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 23s 384ms/step - loss: 0.0813 - sparse_categorical_accuracy: 0.9705 - val_loss: 1.4517 - val_sparse_categorical_accuracy: 0.7046
# Epoch 92/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 22s 372ms/step - loss: 0.1059 - sparse_categorical_accuracy: 0.9623 - val_loss: 1.5236 - val_sparse_categorical_accuracy: 0.7092
# Epoch 93/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 41s 375ms/step - loss: 0.0884 - sparse_categorical_accuracy: 0.9681 - val_loss: 1.3506 - val_sparse_categorical_accuracy: 0.7241
# Epoch 94/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 23s 382ms/step - loss: 0.0778 - sparse_categorical_accuracy: 0.9715 - val_loss: 1.3772 - val_sparse_categorical_accuracy: 0.7306
# Epoch 95/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 40s 371ms/step - loss: 0.0712 - sparse_categorical_accuracy: 0.9740 - val_loss: 1.4114 - val_sparse_categorical_accuracy: 0.7250
# Epoch 96/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 42s 381ms/step - loss: 0.0766 - sparse_categorical_accuracy: 0.9722 - val_loss: 1.4423 - val_sparse_categorical_accuracy: 0.7177
# Epoch 97/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 41s 378ms/step - loss: 0.0712 - sparse_categorical_accuracy: 0.9741 - val_loss: 1.4356 - val_sparse_categorical_accuracy: 0.7306
# Epoch 98/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 23s 387ms/step - loss: 0.0700 - sparse_categorical_accuracy: 0.9744 - val_loss: 1.4497 - val_sparse_categorical_accuracy: 0.7252
# Epoch 99/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 23s 375ms/step - loss: 0.0651 - sparse_categorical_accuracy: 0.9762 - val_loss: 1.4915 - val_sparse_categorical_accuracy: 0.7171
# Epoch 100/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 41s 374ms/step - loss: 0.0686 - sparse_categorical_accuracy: 0.9748 - val_loss: 1.4810 - val_sparse_categorical_accuracy: 0.7274

# %%
# Визуализация
def process_images(model, count=1):
    indexes = np.random.randint(0, len(x_val), count)
    predict = np.argmax(model.predict(x_val[indexes]), axis=-1)
    orig = labels_to_rgb(predict[..., None])
    fig, axs = plt.subplots(3, count, figsize=(25, 15))
    for i in range(count):
        axs[0, 0].set_title('Результат работы модели:')
        axs[0, i].imshow(orig[i])
        axs[0, i].axis('off')
        axs[1, 0].set_title('Оригинальное сегментированное')
        axs[1, i].imshow(val_segments[indexes[i]])
        axs[1, i].axis('off')
        axs[2, 0].set_title('Оригинальное изображение')
        axs[2, i].imshow(val_images[indexes[i]])
        axs[2, i].axis('off')
    plt.show()
    
# Графики обучения
plt.figure(figsize=(14, 7))
plt.plot(history.history['sparse_categorical_accuracy'])
plt.plot(history.history['val_sparse_categorical_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()
# Результаты сегментации
process_images(model_improved, 5)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step
